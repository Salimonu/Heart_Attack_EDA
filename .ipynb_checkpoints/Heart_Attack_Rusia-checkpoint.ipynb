# %% [markdown]
# # EXPLORATORY DATA ANALYSIS OF HEART ATTACK IN RUSSIA YOUTH AND ADULTS.

# %% [markdown]
# ### Goal of the Analysis.
# - To identify the risk factors for heart attack.
# - To identify the correlation between lifestyle and heart diseases, etc

# %% [markdown]
# ### Steps for EDA in this notebook.
# 1. Understand the Dataset: Shape & Overview.
# 2. Check for Missing Values & Data Types: Identify nulls, Visualize missing values, split the dataset into 2 (dataset with no alcohol report and dataset with alcohol report).
# 3. Data Cleaning:
# Convert categorical variables to proper types using astype('category').
#
# Normalize/standardize numeric features if needed (for ML).
#
# Fix inconsistencies (e.g., "Male", "male", "M").

# %%
# import packages.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the data.
df = pd.read_csv("heart_attack_russia_youth_vs_adult.csv")

# read the shape of data.
df.shape
# Out:
# (50000, 30)

# %%
# overview of data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Region                 50000 non-null  object
#  4   Blood_Pressure         50000 non-null  float64
#  5   Cholesterol            50000 non-null  float64
#  6   BMI                    50000 non-null  float64
#  7   Heart_Rate             50000 non-null  int64
#  8   Exercise_Level         50000 non-null  object
#  9   Smoking                50000 non-null  bool
#  10  Alcohol_Consumption    24976 non-null  object
#  11  Diabetes               50000 non-null  bool
#  12  Family_History         50000 non-null  bool
#  13  Stress_Level           50000 non-null  int64
#  14  Heart_Attack           50000 non-null  bool
#  15  Angina                 50000 non-null  bool
#  16  Heart_Disease_History  50000 non-null  bool
#  17  Diet                   50000 non-null  object
#  18  Sleep_Hours            50000 non-null  float64
#  19  Occupation             50000 non-null  object
#  20  Income_Level           50000 non-null  object
#  21  Physical_Activity      50000 non-null  object
#  22  Education_Level        50000 non-null  object
#  23  Marital_Status         50000 non-null  object
#  24  Urban_Rural            50000 non-null  object
#  25  Medication             50000 non-null  bool
#  26  Health_Awareness       50000 non-null  int64
#  27  Daily_Water_Intake     50000 non-null  float64
#  28  Mental_Health          50000 non-null  int64
#  29  Obesity                50000 non-null  bool
# dtypes: bool(8), float64(5), int64(6), object(11)
# memory usage: 8.8+ MB

# %%
# read the head part of the data.
df.head()
# Out:
#    ID  Age  Gender Region  Blood_Pressure  Cholesterol   BMI  Heart_Rate  \
# 0   1   50    Male  Rural           110.0        196.5  15.9          76
# 1   2   40  Female  Urban           138.8        157.5  27.1          82
# 2   3   26    Male  Rural           116.0        210.1  27.2          71
# 3   4   54  Female  Rural           133.5        170.5  26.0          74
# 4   5   19  Female  Urban           108.0        224.5  27.5          67
#
#   Exercise_Level  Smoking  ... Income_Level  Physical_Activity  \
# 0           High    False  ...          Low                Low
# 1       Moderate    False  ...          Low           Moderate
# 2       Moderate    False  ...       Middle               High
# 3       Moderate     True  ...       Middle           Moderate
# 4            Low    False  ...       Middle                Low
#
#    Education_Level  Marital_Status  Urban_Rural  Medication  Health_Awareness  \
# 0          Primary         Married        Rural       False                 5
# 1           Higher         Married        Urban       False                 1
# 2          Primary         Married        Urban       False                 4
# 3           Higher         Married        Urban       False                 2
# 4           Higher         Widowed        Urban       False                 4
#
#   Daily_Water_Intake  Mental_Health Obesity
# 0                2.3              5   False
# 1                5.0              4   False
# 2                2.4              8   False
# 3                2.7              6    True
# 4                3.5              4    True
#
# [5 rows x 30 columns]

# %%
# read the columns.
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Region', 'Blood_Pressure', 'Cholesterol', 'BMI',
#        'Heart_Rate', 'Exercise_Level', 'Smoking', 'Alcohol_Consumption',
#        'Diabetes', 'Family_History', 'Stress_Level', 'Heart_Attack', 'Angina',
#        'Heart_Disease_History', 'Diet', 'Sleep_Hours', 'Occupation',
#        'Income_Level', 'Physical_Activity', 'Education_Level',
#        'Marital_Status', 'Urban_Rural', 'Medication', 'Health_Awareness',
#        'Daily_Water_Intake', 'Mental_Health', 'Obesity'],
#       dtype='object')

# %%
# Read number of entries.
df.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
# Check for the missing values.
df.isna().sum()
# Out:
# ID                           0
# Age                          0
# Gender                       0
# Region                       0
# Blood_Pressure               0
# Cholesterol                  0
# BMI                          0
# Heart_Rate                   0
# Exercise_Level               0
# Smoking                      0
# Alcohol_Consumption      25024
# Diabetes                     0
# Family_History               0
# Stress_Level                 0
# Heart_Attack                 0
# Angina                       0
# Heart_Disease_History        0
# Diet                         0
# Sleep_Hours                  0
# Occupation                   0
# Income_Level                 0
# Physical_Activity            0
# Education_Level              0
# Marital_Status               0
# Urban_Rural                  0
# Medication                   0
# Health_Awareness             0
# Daily_Water_Intake           0
# Mental_Health                0
# Obesity                      0
# dtype: int64

# %%
# Visualize missing values.
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Calculate the percentage of individuals with no report of alcohol consumption.
(df["Alcohol_Consumption"].isna().sum()/len(df))*100
# Out:
# np.float64(50.048)

# %%
# check for duplicate entries for all columns.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for duplicate entries for ID column only.
df.duplicated(subset="ID").sum()
# Out:
# np.int64(0)

# %%
# check the descriptive analysis of the data.
df.describe().T
# Out:
#                       count          mean           std   min       25%  \
# ID                  50000.0  25000.500000  14433.901067   1.0  12500.75
# Age                 50000.0     35.991820     14.110139  12.0     24.00
# Blood_Pressure      50000.0    120.058636     14.975835  60.0    109.90
# Cholesterol         50000.0    199.852762     49.998331 -18.7    166.10
# BMI                 50000.0     24.983912      5.003784   2.9     21.60
# Heart_Rate          50000.0     79.988980     11.804567  60.0     70.00
# Stress_Level        50000.0      5.503700      2.870741   1.0      3.00
# Sleep_Hours         50000.0      7.011464      1.740651   4.0      5.50
# Health_Awareness    50000.0      3.007100      1.410351   1.0      2.00
# Daily_Water_Intake  50000.0      2.997782      1.149608   1.0      2.00
# Mental_Health       50000.0      5.486740      2.860760   1.0      3.00
#
#                          50%       75%      max
# ID                  25000.50  37500.25  50000.0
# Age                    36.00     48.00     60.0
# Blood_Pressure        120.05    130.20    188.4
# Cholesterol           199.90    233.50    398.8
# BMI                    25.00     28.40     46.1
# Heart_Rate             80.00     90.00    100.0
# Stress_Level            6.00      8.00     10.0
# Sleep_Hours             7.00      8.50     10.0
# Health_Awareness        3.00      4.00      5.0
# Daily_Water_Intake      3.00      4.00      5.0
# Mental_Health           5.00      8.00     10.0

# %%
# Filter individuals with no report of alcohol.

no_alcohol_report = df["Alcohol_Consumption"].isna()

df_alcohol_unknown = df[no_alcohol_report]
df_alcohol_unknown.head().T
# Out:
#                                1          4         5           7          9
# ID                             2          5         6           8         10
# Age                           40         19        32          30         22
# Gender                    Female     Female    Female      Female       Male
# Region                     Urban      Urban     Rural       Rural      Rural
# Blood_Pressure             138.8      108.0     104.3       100.3      138.3
# Cholesterol                157.5      224.5     257.4       268.0      196.7
# BMI                         27.1       27.5      17.6        14.5       17.5
# Heart_Rate                    82         67        60          68         88
# Exercise_Level          Moderate        Low       Low    Moderate        Low
# Smoking                    False      False      True       False      False
# Alcohol_Consumption          NaN        NaN       NaN         NaN        NaN
# Diabetes                   False      False      True       False      False
# Family_History              True       True     False       False       True
# Stress_Level                   5          1        10           8          3
# Heart_Attack               False      False     False       False      False
# Angina                      True      False     False       False      False
# Heart_Disease_History      False      False     False       False      False
# Diet                   Unhealthy  Unhealthy   Healthy       Mixed  Unhealthy
# Sleep_Hours                  5.5        5.9       9.9         5.9        9.7
# Occupation              Employed   Employed  Employed  Unemployed   Employed
# Income_Level                 Low     Middle       Low      Middle        Low
# Physical_Activity       Moderate        Low      High    Moderate   Moderate
# Education_Level           Higher     Higher   Primary     Primary    Primary
# Marital_Status           Married    Widowed   Married      Single     Single
# Urban_Rural                Urban      Urban     Urban       Urban      Rural
# Medication                 False      False      True       False      False
# Health_Awareness               1          4         1           2          4
# Daily_Water_Intake           5.0        3.5       1.3         2.5        3.8
# Mental_Health                  4          4         7           1          2
# Obesity                    False       True     False       False      False

# %%
# export the file of individuals with no alcohol report as csv
df_alcohol_unknown.to_csv("heart_attack_no_alcohol_report.csv", index=False)

# %%
# Filter individuals with report of alcohol.
# METHOD 1.

df_alcohol_known = df.dropna(subset="Alcohol_Consumption")
df_alcohol_known.head().T
# Out:
#                                 0          2         3           6         8
# ID                              1          3         4           7         9
# Age                            50         26        54          50        34
# Gender                       Male       Male    Female        Male      Male
# Region                      Rural      Rural     Rural    Suburban     Urban
# Blood_Pressure              110.0      116.0     133.5       116.8     131.8
# Cholesterol                 196.5      210.1     170.5       206.9     244.6
# BMI                          15.9       27.2      26.0        27.9      24.4
# Heart_Rate                     76         71        74          75        65
# Exercise_Level               High   Moderate  Moderate        High       Low
# Smoking                     False      False      True        True     False
# Alcohol_Consumption      Moderate   Moderate  Moderate       Heavy     Heavy
# Diabetes                    False       True     False       False     False
# Family_History              False      False      True       False     False
# Stress_Level                    8          8         5           5         2
# Heart_Attack                False      False     False        True      True
# Angina                      False      False     False       False     False
# Heart_Disease_History       False      False     False        True     False
# Diet                    Unhealthy  Unhealthy   Healthy   Unhealthy     Mixed
# Sleep_Hours                   9.4        8.8       8.2         9.7       6.6
# Occupation             Unemployed   Employed   Student  Unemployed  Employed
# Income_Level                  Low     Middle    Middle      Middle      High
# Physical_Activity             Low       High  Moderate    Moderate  Moderate
# Education_Level           Primary    Primary    Higher     Primary   Primary
# Marital_Status            Married    Married   Married     Married   Married
# Urban_Rural                 Rural      Urban     Urban       Urban     Rural
# Medication                  False      False     False        True     False
# Health_Awareness                5          4         2           1         1
# Daily_Water_Intake            2.3        2.4       2.7         1.7       4.7
# Mental_Health                   5          8         6          10         7
# Obesity                     False      False      True        True     False

# %%
# Filter individuals with report of alcohol.
# METHOD 2.

no_alcohol_report = df["Alcohol_Consumption"].isna()

df_alcohol_known_2 = df[~no_alcohol_report]
df_alcohol_known_2.head().T
# Out:
#                                 0          2         3           6         8
# ID                              1          3         4           7         9
# Age                            50         26        54          50        34
# Gender                       Male       Male    Female        Male      Male
# Region                      Rural      Rural     Rural    Suburban     Urban
# Blood_Pressure              110.0      116.0     133.5       116.8     131.8
# Cholesterol                 196.5      210.1     170.5       206.9     244.6
# BMI                          15.9       27.2      26.0        27.9      24.4
# Heart_Rate                     76         71        74          75        65
# Exercise_Level               High   Moderate  Moderate        High       Low
# Smoking                     False      False      True        True     False
# Alcohol_Consumption      Moderate   Moderate  Moderate       Heavy     Heavy
# Diabetes                    False       True     False       False     False
# Family_History              False      False      True       False     False
# Stress_Level                    8          8         5           5         2
# Heart_Attack                False      False     False        True      True
# Angina                      False      False     False       False     False
# Heart_Disease_History       False      False     False        True     False
# Diet                    Unhealthy  Unhealthy   Healthy   Unhealthy     Mixed
# Sleep_Hours                   9.4        8.8       8.2         9.7       6.6
# Occupation             Unemployed   Employed   Student  Unemployed  Employed
# Income_Level                  Low     Middle    Middle      Middle      High
# Physical_Activity             Low       High  Moderate    Moderate  Moderate
# Education_Level           Primary    Primary    Higher     Primary   Primary
# Marital_Status            Married    Married   Married     Married   Married
# Urban_Rural                 Rural      Urban     Urban       Urban     Rural
# Medication                  False      False     False        True     False
# Health_Awareness                5          4         2           1         1
# Daily_Water_Intake            2.3        2.4       2.7         1.7       4.7
# Mental_Health                   5          8         6          10         7
# Obesity                     False      False      True        True     False

# %%
# Export the file of individuals with alcohol report as csv.
df_alcohol_known.to_csv("heart_attack_with_alcohol_report.csv", index=False)

# %%
df.head(20).T
# Out:
#                                0          1          2         3          4   \
# ID                              1          2          3         4          5
# Age                            50         40         26        54         19
# Gender                       Male     Female       Male    Female     Female
# Region                      Rural      Urban      Rural     Rural      Urban
# Blood_Pressure              110.0      138.8      116.0     133.5      108.0
# Cholesterol                 196.5      157.5      210.1     170.5      224.5
# BMI                          15.9       27.1       27.2      26.0       27.5
# Heart_Rate                     76         82         71        74         67
# Exercise_Level               High   Moderate   Moderate  Moderate        Low
# Smoking                     False      False      False      True      False
# Alcohol_Consumption      Moderate        NaN   Moderate  Moderate        NaN
# Diabetes                    False      False       True     False      False
# Family_History              False       True      False      True       True
# Stress_Level                    8          5          8         5          1
# Heart_Attack                False      False      False     False      False
# Angina                      False       True      False     False      False
# Heart_Disease_History       False      False      False     False      False
# Diet                    Unhealthy  Unhealthy  Unhealthy   Healthy  Unhealthy
# Sleep_Hours                   9.4        5.5        8.8       8.2        5.9
# Occupation             Unemployed   Employed   Employed   Student   Employed
# Income_Level                  Low        Low     Middle    Middle     Middle
# Physical_Activity             Low   Moderate       High  Moderate        Low
# Education_Level           Primary     Higher    Primary    Higher     Higher
# Marital_Status            Married    Married    Married   Married    Widowed
# Urban_Rural                 Rural      Urban      Urban     Urban      Urban
# Medication                  False      False      False     False      False
# Health_Awareness                5          1          4         2          4
# Daily_Water_Intake            2.3        5.0        2.4       2.7        3.5
# Mental_Health                   5          4          8         6          4
# Obesity                     False      False      False      True       True
#
#                              5           6           7         8          9   \
# ID                            6           7           8         9         10
# Age                          32          50          30        34         22
# Gender                   Female        Male      Female      Male       Male
# Region                    Rural    Suburban       Rural     Urban      Rural
# Blood_Pressure            104.3       116.8       100.3     131.8      138.3
# Cholesterol               257.4       206.9       268.0     244.6      196.7
# BMI                        17.6        27.9        14.5      24.4       17.5
# Heart_Rate                   60          75          68        65         88
# Exercise_Level              Low        High    Moderate       Low        Low
# Smoking                    True        True       False     False      False
# Alcohol_Consumption         NaN       Heavy         NaN     Heavy        NaN
# Diabetes                   True       False       False     False      False
# Family_History            False       False       False     False       True
# Stress_Level                 10           5           8         2          3
# Heart_Attack              False        True       False      True      False
# Angina                    False       False       False     False      False
# Heart_Disease_History     False        True       False     False      False
# Diet                    Healthy   Unhealthy       Mixed     Mixed  Unhealthy
# Sleep_Hours                 9.9         9.7         5.9       6.6        9.7
# Occupation             Employed  Unemployed  Unemployed  Employed   Employed
# Income_Level                Low      Middle      Middle      High        Low
# Physical_Activity          High    Moderate    Moderate  Moderate   Moderate
# Education_Level         Primary     Primary     Primary   Primary    Primary
# Marital_Status          Married     Married      Single   Married     Single
# Urban_Rural               Urban       Urban       Urban     Rural      Rural
# Medication                 True        True       False     False      False
# Health_Awareness              1           1           2         1          4
# Daily_Water_Intake          1.3         1.7         2.5       4.7        3.8
# Mental_Health                 7          10           1         7          2
# Obesity                   False        True       False     False      False
#
#                                10        11        12          13          14  \
# ID                             11        12        13          14          15
# Age                            22        35        47          51          35
# Gender                     Female    Female      Male        Male        Male
# Region                      Rural     Rural     Rural       Rural       Rural
# Blood_Pressure              128.8     141.0     130.4       113.8       121.7
# Cholesterol                 233.1     141.9     229.5       231.2       274.6
# BMI                          19.6      24.0      20.9        28.4        31.5
# Heart_Rate                     90        73        99          75          97
# Exercise_Level           Moderate  Moderate  Moderate         Low    Moderate
# Smoking                     False     False     False        True       False
# Alcohol_Consumption      Moderate     Heavy       NaN         NaN         NaN
# Diabetes                    False     False     False       False       False
# Family_History              False     False      True       False        True
# Stress_Level                    5         3         3          10           3
# Heart_Attack                False     False     False       False       False
# Angina                      False     False     False        True       False
# Heart_Disease_History        True     False      True       False       False
# Diet                    Unhealthy   Healthy     Mixed   Unhealthy       Mixed
# Sleep_Hours                   5.0       5.5       8.8         6.7         5.5
# Occupation             Unemployed  Employed  Employed  Unemployed  Unemployed
# Income_Level               Middle    Middle    Middle         Low      Middle
# Physical_Activity             Low       Low       Low         Low    Moderate
# Education_Level           Primary   Primary    Higher   Secondary   Secondary
# Marital_Status            Married  Divorced   Married      Single     Married
# Urban_Rural                 Urban     Rural     Urban       Urban       Rural
# Medication                   True     False     False       False       False
# Health_Awareness                4         4         2           5           5
# Daily_Water_Intake            1.0       3.8       4.9         4.8         1.3
# Mental_Health                   8         6         9          10           1
# Obesity                      True     False     False       False       False
#
#                                15         16          17        18        19
# ID                             16         17          18        19        20
# Age                            14         33          13        35        55
# Gender                     Female     Female      Female    Female    Female
# Region                   Suburban      Rural       Urban     Urban     Urban
# Blood_Pressure              121.9      137.8       121.3     103.7     100.0
# Cholesterol                 242.1      184.7       180.8     209.7     134.7
# BMI                          18.2       18.7        22.5      26.8      30.0
# Heart_Rate                     73         64          69        91        92
# Exercise_Level           Moderate        Low         Low  Moderate  Moderate
# Smoking                     False      False       False      True     False
# Alcohol_Consumption         Heavy      Heavy         NaN  Moderate       NaN
# Diabetes                     True      False       False      True     False
# Family_History              False       True       False      True      True
# Stress_Level                    2          6           7         4         7
# Heart_Attack                 True      False       False     False     False
# Angina                      False      False       False     False     False
# Heart_Disease_History       False      False       False     False     False
# Diet                      Healthy  Unhealthy       Mixed   Healthy   Healthy
# Sleep_Hours                   8.0        8.4         9.3       4.6       6.5
# Occupation             Unemployed   Employed  Unemployed   Student  Employed
# Income_Level                  Low        Low        High       Low    Middle
# Physical_Activity             Low   Moderate         Low  Moderate       Low
# Education_Level         Secondary     Higher      Higher    Higher    Higher
# Marital_Status            Married     Single     Married   Married    Single
# Urban_Rural                 Rural      Rural       Rural     Rural     Urban
# Medication                   True      False       False     False     False
# Health_Awareness                1          5           5         4         4
# Daily_Water_Intake            1.4        3.5         4.3       1.8       2.9
# Mental_Health                   2          2           1         4         5
# Obesity                     False      False       False      True     False

# %% [markdown]
# ### 3. Convert categorical variables (norminal and ordinal) to proper types.

# %%
# check the dtype of df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  object
#  3   Region                 50000 non-null  object
#  4   Blood_Pressure         50000 non-null  float64
#  5   Cholesterol            50000 non-null  float64
#  6   BMI                    50000 non-null  float64
#  7   Heart_Rate             50000 non-null  int64
#  8   Exercise_Level         50000 non-null  object
#  9   Smoking                50000 non-null  bool
#  10  Alcohol_Consumption    24976 non-null  object
#  11  Diabetes               50000 non-null  bool
#  12  Family_History         50000 non-null  bool
#  13  Stress_Level           50000 non-null  int64
#  14  Heart_Attack           50000 non-null  bool
#  15  Angina                 50000 non-null  bool
#  16  Heart_Disease_History  50000 non-null  bool
#  17  Diet                   50000 non-null  object
#  18  Sleep_Hours            50000 non-null  float64
#  19  Occupation             50000 non-null  object
#  20  Income_Level           50000 non-null  object
#  21  Physical_Activity      50000 non-null  object
#  22  Education_Level        50000 non-null  object
#  23  Marital_Status         50000 non-null  object
#  24  Urban_Rural            50000 non-null  object
#  25  Medication             50000 non-null  bool
#  26  Health_Awareness       50000 non-null  int64
#  27  Daily_Water_Intake     50000 non-null  float64
#  28  Mental_Health          50000 non-null  int64
#  29  Obesity                50000 non-null  bool
# dtypes: bool(8), float64(5), int64(6), object(11)
# memory usage: 8.8+ MB

# %%
# Get a list of categorical variables.

Nominal_variables = ["Gender", "Region", "Diet", "Occupation", "Marital_Status", "Urban_Rural"]
Ordinal_variables = ["Exercise_Level", "Alcohol_Consumption", "Income_Level", "Physical_Activity", "Education_Level"]

# %%
# convert the norminal variables with object dtype to categorical dtype.
# - to reduce memory usage
# - for meaningful data analysis and visualization.


for var in Nominal_variables:
    df[var] = df[var].astype('category')

# %%
# confirm if the norminal variables with object dtype (["Gender", "Region", "Diet", "Occupation", "Marital_Status", "Urban_Rural"])
# were converted to categorical dtype.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  category
#  3   Region                 50000 non-null  category
#  4   Blood_Pressure         50000 non-null  float64
#  5   Cholesterol            50000 non-null  float64
#  6   BMI                    50000 non-null  float64
#  7   Heart_Rate             50000 non-null  int64
#  8   Exercise_Level         50000 non-null  object
#  9   Smoking                50000 non-null  bool
#  10  Alcohol_Consumption    24976 non-null  object
#  11  Diabetes               50000 non-null  bool
#  12  Family_History         50000 non-null  bool
#  13  Stress_Level           50000 non-null  int64
#  14  Heart_Attack           50000 non-null  bool
#  15  Angina                 50000 non-null  bool
#  16  Heart_Disease_History  50000 non-null  bool
#  17  Diet                   50000 non-null  category
#  18  Sleep_Hours            50000 non-null  float64
#  19  Occupation             50000 non-null  category
#  20  Income_Level           50000 non-null  object
#  21  Physical_Activity      50000 non-null  object
#  22  Education_Level        50000 non-null  object
#  23  Marital_Status         50000 non-null  category
#  24  Urban_Rural            50000 non-null  category
#  25  Medication             50000 non-null  bool
#  26  Health_Awareness       50000 non-null  int64
#  27  Daily_Water_Intake     50000 non-null  float64
#  28  Mental_Health          50000 non-null  int64
#  29  Obesity                50000 non-null  bool
# dtypes: bool(8), category(6), float64(5), int64(6), object(5)
# memory usage: 6.8+ MB

# %%
Ordinal_variables = ["Exercise_Level", "Alcohol_Consumption", "Income_Level", "Physical_Activity", "Education_Level"]

# %%
# Check the categories used for each variable.

for var in Ordinal_variables:
    print(df[var].value_counts())
# Out:
# Exercise_Level
# Moderate    24946
# Low         15100
# High         9954
# Name: count, dtype: int64
# Alcohol_Consumption
# Moderate    20022
# Heavy        4954
# Name: count, dtype: int64
# Income_Level
# Middle    20025
# Low       19863
# High      10112
# Name: count, dtype: int64
# Physical_Activity
# Moderate    24828
# Low         15158
# High        10014
# Name: count, dtype: int64
# Education_Level
# Secondary    20064
# Primary      14983
# Higher       14953
# Name: count, dtype: int64

# %%
# Assign the above levels to each variable.

Exercise_Levels = ['Low', 'Moderate', 'High'] 
Alcohol_Consumption_levels = ['NaN','Moderate', 'Heavy']
Income_Levels = ['Low', 'Middle', 'High']
Physical_Activity_levels = ['Low', 'Moderate', 'High']
Education_Levels = ['Primary', 'Secondary', 'Higher']

# %%
# Set the orders for the ordinal variables with object dtype
# - to reduce memory usage
# - for meaningful data analysis and visualization.

# Import the class.
from pandas.api.types import CategoricalDtype

# Set an instance for the class to specify orders.
Ordinal_variables_orders = [Exercise_Levels, Alcohol_Consumption_levels, Income_Levels, Physical_Activity_levels, Education_Levels]

Exercise_Levels_order = CategoricalDtype(categories=Exercise_Levels, ordered=True)
Alcohol_Consumption_levels_order = CategoricalDtype(categories=Alcohol_Consumption_levels, ordered=True)
Income_Levels_order = CategoricalDtype(categories=Income_Levels, ordered=True)
Physical_Activity_levels_order = CategoricalDtype(categories=Physical_Activity_levels, ordered=True)
Education_Levels_order = CategoricalDtype(categories=Education_Levels, ordered=True)

# %%
# Set the orders for the ordinal variables columns with object dtype

df["Exercise_Level"] = df["Exercise_Level"].astype(Exercise_Levels_order)
df["Alcohol_Consumption"] = df["Alcohol_Consumption"].astype(Alcohol_Consumption_levels_order)
df["Income_Level"] = df["Income_Level"].astype(Income_Levels_order)
df["Physical_Activity"] = df["Physical_Activity"].astype(Physical_Activity_levels_order)
df["Education_Level"] = df["Education_Level"].astype(Education_Levels_order)

# %%
# confirm if the ordinal variables with object dtype (["Exercise_Level", "Alcohol_Consumption", 
# "Income_Level", "Physical_Activity", "Education_Level"]) were converted to ordinal dtype.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  int64
#  1   Age                    50000 non-null  int64
#  2   Gender                 50000 non-null  category
#  3   Region                 50000 non-null  category
#  4   Blood_Pressure         50000 non-null  float64
#  5   Cholesterol            50000 non-null  float64
#  6   BMI                    50000 non-null  float64
#  7   Heart_Rate             50000 non-null  int64
#  8   Exercise_Level         50000 non-null  category
#  9   Smoking                50000 non-null  bool
#  10  Alcohol_Consumption    24976 non-null  category
#  11  Diabetes               50000 non-null  bool
#  12  Family_History         50000 non-null  bool
#  13  Stress_Level           50000 non-null  int64
#  14  Heart_Attack           50000 non-null  bool
#  15  Angina                 50000 non-null  bool
#  16  Heart_Disease_History  50000 non-null  bool
#  17  Diet                   50000 non-null  category
#  18  Sleep_Hours            50000 non-null  float64
#  19  Occupation             50000 non-null  category
#  20  Income_Level           50000 non-null  category
#  21  Physical_Activity      50000 non-null  category
#  22  Education_Level        50000 non-null  category
#  23  Marital_Status         50000 non-null  category
#  24  Urban_Rural            50000 non-null  category
#  25  Medication             50000 non-null  bool
#  26  Health_Awareness       50000 non-null  int64
#  27  Daily_Water_Intake     50000 non-null  float64
#  28  Mental_Health          50000 non-null  int64
#  29  Obesity                50000 non-null  bool
# dtypes: bool(8), category(11), float64(5), int64(6)
# memory usage: 5.1 MB

# %%
# To-Do
# Fix inconsistencies (e.g., "Male", "male", "M")

# %% [markdown]
# ## INSIGHTS

# %% [markdown]
# 1. 50% of the individuals in the dataset have no report about their alcohol consumption status.

# %% [markdown]
# ### QUESTIONS
# - how to filter a dataframe based on a column by dropping the subset with null values.
